# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold, cross_validate
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures

# %%
df = pd.read_csv("./Wine_red.csv", sep=';')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
features = df.drop('quality',axis=1)
targets = df.quality

# %%
polys = PolynomialFeatures(2, interaction_only=True)
features_engineered = polys.fit_transform(features)
cols = polys.get_feature_names(features.columns)
features_engineered = pd.DataFrame(features_engineered, columns=cols)
features_engineered.head()
# Out:
#      1  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  1.0            7.4              0.70         0.00             1.9
# 1  1.0            7.8              0.88         0.00             2.6
# 2  1.0            7.8              0.76         0.04             2.3
# 3  1.0           11.2              0.28         0.56             1.9
# 4  1.0            7.4              0.70         0.00             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#          ...          total sulfur dioxide density  total sulfur dioxide pH  \
# 0        ...                               33.9252                   119.34
# 1        ...                               66.7856                   214.40
# 2        ...                               53.8380                   176.04
# 3        ...                               59.8800                   189.60
# 4        ...                               33.9252                   119.34
#
#    total sulfur dioxide sulphates  total sulfur dioxide alcohol  density pH  \
# 0                           19.04                         319.6    3.502278
# 1                           45.56                         656.6    3.189760
# 2                           35.10                         529.2    3.250220
# 3                           34.80                         588.0    3.153680
# 4                           19.04                         319.6    3.502278
#
#    density sulphates  density alcohol  pH sulphates  pH alcohol  \
# 0           0.558768          9.37932        1.9656      32.994
# 1           0.677824          9.76864        2.1760      31.360
# 2           0.648050          9.77060        2.1190      31.948
# 3           0.578840          9.78040        1.8328      30.968
# 4           0.558768          9.37932        1.9656      32.994
#
#    sulphates alcohol
# 0              5.264
# 1              6.664
# 2              6.370
# 3              5.684
# 4              5.264
#
# [5 rows x 67 columns]

# %%
# drop features with zero standard deviation
lx = (features_engineered.std() == 0)
drop_cols = features_engineered.columns[lx]
features_engineered = features_engineered.drop(drop_cols,axis=1)

# %%
# standardize features
features_engineered = (features_engineered - features_engineered.mean())/features_engineered.std()

# %%
features_engineered.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.528194          0.961576    -1.391037       -0.453077  -0.243630
# 1      -0.298454          1.966827    -1.391037        0.043403   0.223805
# 2      -0.298454          1.296660    -1.185699       -0.169374   0.096323
# 3       1.654339         -1.384011     1.483689       -0.453077  -0.264878
# 4      -0.528194          0.961576    -1.391037       -0.453077  -0.243630
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.466047             -0.379014  0.558100  1.288240  -0.579025
# 1             0.872365              0.624168  0.028252 -0.719708   0.128910
# 2            -0.083643              0.228975  0.134222 -0.331073  -0.048074
# 3             0.107558              0.411372  0.664069 -0.978798  -0.461036
# 4            -0.466047             -0.379014  0.558100  1.288240  -0.579025
#
#          ...          total sulfur dioxide density  total sulfur dioxide pH  \
# 0        ...                             -0.378041                -0.318888
# 1        ...                              0.624116                 0.567921
# 2        ...                              0.229248                 0.210063
# 3        ...                              0.413513                 0.336563
# 4        ...                             -0.378041                -0.318888
#
#    total sulfur dioxide sulphates  total sulfur dioxide alcohol  density pH  \
# 0                       -0.466169                     -0.469886    1.330644
# 1                        0.583123                      0.535341   -0.727649
# 2                        0.169262                      0.155323   -0.329450
# 3                        0.157392                      0.330716   -0.965278
# 4                       -0.466169                     -0.469886    1.330644
#
#    density sulphates  density alcohol  pH sulphates  pH alcohol  \
# 0          -0.575015        -0.959307     -0.393794   -0.368454
# 1           0.128665        -0.589072      0.003660   -0.756503
# 2          -0.047314        -0.587208     -0.104015   -0.616863
# 3          -0.456379        -0.577888     -0.644658   -0.849597
# 4          -0.575015        -0.959307     -0.393794   -0.368454
#
#    sulphates alcohol
# 0          -0.837776
# 1          -0.110527
# 2          -0.263249
# 3          -0.619601
# 4          -0.837776
#
# [5 rows x 66 columns]

# %%
lr = LinearRegression()

# %%
results = cross_validate(lr, features_engineered,targets,return_train_score=True)
# Out:
# C:\Users\rileyma\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)

# %%
R2_train = results['train_score'].mean()

# %%
R2_test = results['test_score'].mean()

# %%
R2_train
# Out:
# 0.4531523214096939

# %%
lr.fit(features_engineered,targets)
coef = pd.Series(lr.coef_, index=features_engineered.columns)

# %%
coef.sort_values(ascending=False)
# Out:
# total sulfur dioxide                        111.950530
# free sulfur dioxide density                  89.493996
# sulphates                                    64.908481
# chlorides density                            59.382580
# citric acid density                          30.382760
# residual sugar                               15.652508
# fixed acidity density                        14.535287
# density pH                                   12.773722
# density alcohol                               6.224390
# volatile acidity density                      4.301363
# fixed acidity pH                              1.659589
# total sulfur dioxide pH                       1.634137
# pH sulphates                                  1.389410
# citric acid alcohol                           1.272608
# free sulfur dioxide alcohol                   1.165908
# fixed acidity sulphates                       0.695004
# volatile acidity alcohol                      0.643912
# fixed acidity total sulfur dioxide            0.576402
# volatile acidity total sulfur dioxide         0.446583
# residual sugar pH                             0.412893
# chlorides alcohol                             0.300255
# residual sugar total sulfur dioxide           0.223858
# fixed acidity residual sugar                  0.219445
# total sulfur dioxide sulphates                0.149316
# residual sugar sulphates                      0.144844
# volatile acidity citric acid                  0.098110
# citric acid total sulfur dioxide              0.077170
# volatile acidity chlorides                    0.040648
# citric acid free sulfur dioxide               0.036893
# volatile acidity sulphates                    0.014435
#                                                ...
# residual sugar free sulfur dioxide           -0.079858
# chlorides sulphates                          -0.120383
# free sulfur dioxide total sulfur dioxide     -0.133142
# volatile acidity free sulfur dioxide         -0.156076
# chlorides free sulfur dioxide                -0.161843
# sulphates alcohol                            -0.165822
# pH alcohol                                   -0.247930
# fixed acidity volatile acidity               -0.284090
# free sulfur dioxide sulphates                -0.346448
# residual sugar alcohol                       -0.470088
# chlorides pH                                 -0.535355
# density                                      -0.537621
# fixed acidity citric acid                    -0.653334
# fixed acidity free sulfur dioxide            -0.655756
# fixed acidity chlorides                      -0.782412
# fixed acidity alcohol                        -0.878976
# volatile acidity pH                          -1.080484
# free sulfur dioxide pH                       -1.195509
# total sulfur dioxide alcohol                 -1.486351
# citric acid pH                               -3.634233
# volatile acidity                             -3.986522
# alcohol                                      -5.646287
# pH                                          -13.245256
# fixed acidity                               -15.377154
# residual sugar density                      -15.968438
# citric acid                                 -27.516352
# chlorides                                   -58.332904
# density sulphates                           -66.543408
# free sulfur dioxide                         -88.119447
# total sulfur dioxide density               -113.412922
# Length: 66, dtype: float64

# %%
coef['alcohol']
# Out:
# -5.646287046768286

# %% [markdown]
# #### this shit is terribly overfitted
