# %%
df = pd.read_csv('./MA490-01.csv', skiprows=3)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2a46ff3718fa> in <module>
# ----> 1 df = read.csv('./MA490-01.csv')
#
# NameError: name 'read' is not defined

# %%
df.tail()
# Out:
#     Username        Last     First Middle Campus Mail    Major Class Year  \
# 20     tangp        Tang  Peicheng    NaN     CM 2662      CPE    SR   Y4
# 21   tylerpk       Tyler   Phillip      K     CM 2678  ME/CPLS    SR   Y4
# 22   wangy16        Wang   Yuankai    NaN     CM 1996       CS    SR   Y4
# 23      xiek         Xie     Kaiyu    NaN     CM 2025       CS    SR   Y3
# 24  youngqom  Youngquist     Oscar      M     CM 2042  CS/CPLS    JR   Y3
#
#      Advisor                     Email
# 20   doering     TANGP@rose-hulman.edu
# 21   moseley   TYLERPK@rose-hulman.edu
# 22     defoe   WANGY16@rose-hulman.edu
# 23    bohner      XIEK@rose-hulman.edu
# 24  chenowet  YOUNGQOM@rose-hulman.edu

# %%
df.shape
# Out:
# (25, 10)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=25, step=1)

# %%
df.columns
# Out:
# Index(['Username', 'Last', 'First', 'Middle', 'Campus Mail', 'Major', 'Class',
#        'Year', 'Advisor', 'Email'],
#       dtype='object')

# %%
df.values
# Out:
# array([['alexanjs', 'Alexander', 'Jarrett', 'S', 'CM 2208', 'CS/MA',
#         'SR', 'Y4', 'chenowet', 'ALEXANJS@rose-hulman.edu'],
#        ['bakerak', 'Baker', 'Adam', 'K', 'CM 1516', 'MA', 'JR', 'Y3',
#         'finn', 'BAKERAK@rose-hulman.edu'],
#        ['chattoa', 'Chattopadhyay', 'Akanksha', nan, 'CM 1581', 'MA',
#         'SR', 'Y3', 'holder1', 'CHATTOA@rose-hulman.edu'],
#        ['chenx5', 'Chen', 'Xiangbei', nan, 'CM 1585', 'CS', 'JR', 'Y3',
#         'taylormt', 'CHENX5@rose-hulman.edu'],
#        ['colledkm', 'Colledge', 'Katana', 'M', 'CM 888', 'ME', 'JR',
#         'Y2', 'white', 'COLLEDKM@rose-hulman.edu'],
#        ['dangw', 'Dang', 'Wenkang', nan, 'CM 634', 'CS', 'SR', 'Y5',
#         'boutell', 'DANGW@rose-hulman.edu'],
#        ['evardl', 'Evard', 'Luke', nan, 'CM 1635', 'CS', 'SR', 'Y3',
#         'taylormt', 'EVARDL@rose-hulman.edu'],
#        ['gishbd', 'Gish', 'Bryan', 'D', 'CM 3223', 'ME', 'SR', 'Y5',
#         'riley1', 'GISHBD@rose-hulman.edu'],
# ...

# %%
df.loc[5:10]
# Out:
#     Username    Last    First Middle Campus Mail Major Class Year   Advisor  \
# 5      dangw    Dang  Wenkang    NaN      CM 634    CS    SR   Y5   boutell
# 6     evardl   Evard     Luke    NaN     CM 1635    CS    SR   Y3  taylormt
# 7     gishbd    Gish    Bryan      D     CM 3223    ME    SR   Y5    riley1
# 8   illiancp  Illian     Cobi      P     CM 2060    MA    SR   Y4  eichholz
# 9       jins     Jin    SiJun    NaN     CM 2420    ME    SR   Y4    kawano
# 10  jonessa1   Jones  Stephen      A     CM 2426    ME    SR   Y4    kawano
#
#                        Email
# 5      DANGW@rose-hulman.edu
# 6     EVARDL@rose-hulman.edu
# 7     GISHBD@rose-hulman.edu
# 8   ILLIANCP@rose-hulman.edu
# 9       JINS@rose-hulman.edu
# 10  JONESSA1@rose-hulman.edu

# %%
df.iloc[5:10]
# Out:
#    Username    Last    First Middle Campus Mail Major Class Year   Advisor  \
# 5     dangw    Dang  Wenkang    NaN      CM 634    CS    SR   Y5   boutell
# 6    evardl   Evard     Luke    NaN     CM 1635    CS    SR   Y3  taylormt
# 7    gishbd    Gish    Bryan      D     CM 3223    ME    SR   Y5    riley1
# 8  illiancp  Illian     Cobi      P     CM 2060    MA    SR   Y4  eichholz
# 9      jins     Jin    SiJun    NaN     CM 2420    ME    SR   Y4    kawano
#
#                       Email
# 5     DANGW@rose-hulman.edu
# 6    EVARDL@rose-hulman.edu
# 7    GISHBD@rose-hulman.edu
# 8  ILLIANCP@rose-hulman.edu
# 9      JINS@rose-hulman.edu

# %%
df.loc[0:5, ['Last', 'Username']]
# Out:
#             Last  Username
# 0      Alexander  alexanjs
# 1          Baker   bakerak
# 2  Chattopadhyay   chattoa
# 3           Chen    chenx5
# 4       Colledge  colledkm
# 5           Dang     dangw

# %%
df.iloc[0:5,[1,0]]
# Out:
#             Last  Username
# 0      Alexander  alexanjs
# 1          Baker   bakerak
# 2  Chattopadhyay   chattoa
# 3           Chen    chenx5
# 4       Colledge  colledkm

# %%
df.Middle
# Out:
# 0       S
# 1       K
# 2     NaN
# 3     NaN
# 4       M
# 5     NaN
# 6     NaN
# 7       D
# 8       P
# 9     NaN
# 10      A
# 11      K
# 12    NaN
# 13      L
# 14      B
# 15      A
# 16      F
# 17      A
# 18      C
# 19    NaN
# 20    NaN
# 21      K
# 22    NaN
# 23    NaN
# 24      M
# Name: Middle, dtype: object

# %%
df.Middle.value_counts()
# Out:
# A    3
# K    3
# M    2
# F    1
# S    1
# P    1
# B    1
# D    1
# L    1
# C    1
# Name: Middle, dtype: int64

# %%
df.Major.value_counts()
# Out:
# MA         6
# CS         5
# ME         4
# CPE        3
# CS/MA      1
# BMTH       1
# CHE/MA     1
# ME/CPLS    1
# MA/CS      1
# CS/CPLS    1
# SE         1
# Name: Major, dtype: int64

# %%
df[df.Major=='CS']
# Out:
#    Username   Last     First Middle Campus Mail Major Class Year   Advisor  \
# 3    chenx5   Chen  Xiangbei    NaN     CM 1585    CS    JR   Y3  taylormt
# 5     dangw   Dang   Wenkang    NaN      CM 634    CS    SR   Y5   boutell
# 6    evardl  Evard      Luke    NaN     CM 1635    CS    SR   Y3  taylormt
# 22  wangy16   Wang   Yuankai    NaN     CM 1996    CS    SR   Y4     defoe
# 23     xiek    Xie     Kaiyu    NaN     CM 2025    CS    SR   Y3    bohner
#
#                       Email
# 3    CHENX5@rose-hulman.edu
# 5     DANGW@rose-hulman.edu
# 6    EVARDL@rose-hulman.edu
# 22  WANGY16@rose-hulman.edu
# 23     XIEK@rose-hulman.edu

# %%
df[df.Major=='SE']
# Out:
#    Username   Last    First Middle Campus Mail Major Class Year Advisor  \
# 15  rileyma  Riley  Michael      A     CM 2574    SE    SR   Y4  bohner
#
#                       Email
# 15  RILEYMA@rose-hulman.edu
