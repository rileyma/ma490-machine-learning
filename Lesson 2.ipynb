# %%
import pandas as pd

# %%
df = pd.read_csv('./Iris-cleaned.csv')

# %%
df
# Out:
#      sepal length  sepal width  petal length  petal width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %% [markdown]
# ## (A) Use .describe() to compute the mean, the standard deviation, the minimum and maximum values and the quartiles of the iris features.

# %%
df.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## (B) How many records of each species are there in the data set? Use .value_counts().

# %%
df.species.value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64

# %% [markdown]
# ANS: 50 for each species, shown above

# %% [markdown]
# ## (C) Plot histograms of the iris feature.

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
# %matplotlib inline

# %%
for feature in df.columns[0:4]:
    df[feature].plot.hist()
    plt.title(feature)
    plt.show()

# %% [markdown]
# ## (D) Plot box plots of the iris sepal length feature grouped by species.

# %%
df.boxplot(column=['sepal length'], by = 'species')

# %% [markdown]
# ## (E) Plot scatter plots of iris features.

# %%
pd.plotting.scatter_matrix(df, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000230C5F83198>,
# ...
#       dtype=object)

# %% [markdown]
# ## (F) Are any of the iris features correlated?

# %%
df.corr()
# Out:
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.109369      0.871754     0.817954
# sepal width      -0.109369     1.000000     -0.420516    -0.356544
# petal length      0.871754    -0.420516      1.000000     0.962757
# petal width       0.817954    -0.356544      0.962757     1.000000

# %% [markdown]
# ANS: Petal width is highly correlated to petal width. Petal length is correlated to sepal length. Petal width is also correlated to sepal length.

# %% [markdown]
# ## (G) Randomize the order of the data.

# %%
df.sample(frac=1.0)
# Out:
#      sepal length  sepal width  petal length  petal width     species
# 14            5.8          4.0           1.2          0.2      setosa
# 71            6.1          2.8           4.0          1.3  versicolor
# 63            6.1          2.9           4.7          1.4  versicolor
# 113           5.7          2.5           5.0          2.0   virginica
# 120           6.9          3.2           5.7          2.3   virginica
# 108           6.7          2.5           5.8          1.8   virginica
# 78            6.0          2.9           4.5          1.5  versicolor
# 105           7.6          3.0           6.6          2.1   virginica
# 99            5.7          2.8           4.1          1.3  versicolor
# 100           6.3          3.3           6.0          2.5   virginica
# 76            6.8          2.8           4.8          1.4  versicolor
# 83            6.0          2.7           5.1          1.6  versicolor
# ...

# %% [markdown]
# ## (H) One-hot-encode the species column.

# %%
pd.get_dummies(df).sample(frac=1.0)
# Out:
#      sepal length  sepal width  petal length  petal width  species_setosa  \
# 24            4.8          3.4           1.9          0.2               1
# 85            6.0          3.4           4.5          1.6               0
# 54            6.5          2.8           4.6          1.5               0
# 5             5.4          3.9           1.7          0.4               1
# 86            6.7          3.1           4.7          1.5               0
# 29            4.7          3.2           1.6          0.2               1
# 137           6.4          3.1           5.5          1.8               0
# 136           6.3          3.4           5.6          2.4               0
# 124           6.7          3.3           5.7          2.1               0
# 120           6.9          3.2           5.7          2.3               0
# 72            6.3          2.5           4.9          1.5               0
# 33            5.5          4.2           1.4          0.2               1
# ...
